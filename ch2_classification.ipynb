# %% [markdown]
# <a href="https://colab.research.google.com/github/ecuirty-kr/1_DataAnalysis/blob/main/ch2_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bigdata_analyst_cert_v2/blob/main/part2/ch2/ch2_classification.ipynb)

# %% [markdown]
# # 1. 문제정의
# - 도서 참고

# %% [markdown]
# # 2. 라이브러리 및 데이터 불러오기

# %%
# 판다스 라이브러리
import pandas as pd

# 데이터 불러오기
# train = pd.read_csv('train.csv')
# test = pd.read_csv('test.csv')
train = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part2/ch2/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part2/ch2/test.csv')

# %%
## 역대급 머리에 안 들어오는 시험 : 빅.분.기 - 실기
## 라이브러리 불러오기
import pandas as pd

## 데이터 불러오기
train = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part2/ch2/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part2/ch2/test.csv')

# %%
## 데이터 샘플 확인(탐색적 데이터 분석 : 데이터 타입, Lable, 행열 개수 등 파악)
train.head()
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
# 3    693  58.0    Private  100313  Some-college             10
# 4  12522  41.0    Private  195661  Some-college             10
#
#        marital.status        occupation relationship   race     sex  \
# 0  Married-civ-spouse    Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse      Craft-repair      Husband  White    Male
# 2             Widowed   Exec-managerial    Unmarried  Black  Female
# 3  Married-civ-spouse   Protective-serv      Husband  White    Male
# 4  Married-civ-spouse  Transport-moving      Husband  White    Male
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          4386             0            40.0  United-States   >50K
# 1             0             0            40.0  United-States  <=50K
# 2             0          1669            38.0  United-States  <=50K
# 3             0          1902            40.0  United-States   >50K
# 4             0             0            54.0  United-States  <=50K

# %% [markdown]
# # 3. 탐색적 데이터 분석(EDA)

# %%
# 데이터 샘플
train.head(3)
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
#
#        marital.status       occupation relationship   race     sex  \
# 0  Married-civ-spouse   Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse     Craft-repair      Husband  White    Male
# 2             Widowed  Exec-managerial    Unmarried  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          4386             0            40.0  United-States   >50K
# 1             0             0            40.0  United-States  <=50K
# 2             0          1669            38.0  United-States  <=50K

# %%
## 데이터 크기 확인
train.shape, test.shape ### (행, 컬럼) 개수 확인
# Out:
# ((29304, 16), (3257, 15))

# %%
## 데이터 자료형 확인
train.info()  ## 수치형, 범쥐형 확인 (수치형:int float | 범주형 : object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29304 entries, 0 to 29303
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              29304 non-null  int64
#  1   age             29292 non-null  float64
#  2   workclass       27642 non-null  object
#  3   fnlwgt          29304 non-null  int64
#  4   education       29304 non-null  object
#  5   education.num   29304 non-null  int64
#  6   marital.status  29304 non-null  object
#  7   occupation      27636 non-null  object
#  8   relationship    29304 non-null  object
#  9   race            29304 non-null  object
#  10  sex             29304 non-null  object
#  11  capital.gain    29304 non-null  int64
#  12  capital.loss    29304 non-null  int64
#  13  hours.per.week  29291 non-null  float64
#  14  native.country  28767 non-null  object
#  15  income          29304 non-null  object
# dtypes: float64(2), int64(5), object(9)
# memory usage: 3.6+ MB

# %%
# 데이터 크기
train.shape, test.shape
# Out:
# ((29304, 16), (3257, 15))

# %%
# 자료형 (타입)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29304 entries, 0 to 29303
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              29304 non-null  int64
#  1   age             29292 non-null  float64
#  2   workclass       27642 non-null  object
#  3   fnlwgt          29304 non-null  int64
#  4   education       29304 non-null  object
#  5   education.num   29304 non-null  int64
#  6   marital.status  29304 non-null  object
#  7   occupation      27636 non-null  object
#  8   relationship    29304 non-null  object
#  9   race            29304 non-null  object
#  10  sex             29304 non-null  object
#  11  capital.gain    29304 non-null  int64
#  12  capital.loss    29304 non-null  int64
#  13  hours.per.week  29291 non-null  float64
#  14  native.country  28767 non-null  object
#  15  income          29304 non-null  object
# dtypes: float64(2), int64(5), object(9)
# memory usage: 3.6+ MB

# %%
## 수치형 데이터의 기초통계량 확인(평균, 최솟값, 최댓값 등)
train.describe()  ## age > 마이너스값 존재
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29292.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.553223  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.628811  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29291.000000
# mean      86.744506       40.434229
# std      401.518928       12.324036
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
test.describe()  ## age.min  양수값 > train age 값에 이상치가 있음을 유추할 수 있음
# Out:
#                  id          age        fnlwgt  education.num  capital.gain  \
# count   3257.000000  3251.000000  3.257000e+03    3257.000000   3257.000000
# mean   16423.704943    38.802830  1.900447e+05      10.079214    931.804728
# std     9535.416746    13.917588  1.057902e+05       2.590118   6496.962999
# min        3.000000    17.000000  1.882700e+04       1.000000      0.000000
# 25%     8078.000000    28.000000  1.186520e+05       9.000000      0.000000
# 50%    16626.000000    37.000000  1.783190e+05      10.000000      0.000000
# 75%    24743.000000    48.000000  2.364360e+05      12.000000      0.000000
# max    32559.000000    90.000000  1.033222e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count   3257.000000     3248.000000
# mean      92.336199       40.468288
# std      415.732721       12.598546
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     3900.000000       99.000000

# %%
# 수치형 컬럼 통계값 확인(train)
train.describe()
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29292.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.553223  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.628811  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29291.000000
# mean      86.744506       40.434229
# std      401.518928       12.324036
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# 수치형 컬럼 통계값 확인(test)
test.describe()
# Out:
#                  id          age        fnlwgt  education.num  capital.gain  \
# count   3257.000000  3251.000000  3.257000e+03    3257.000000   3257.000000
# mean   16423.704943    38.802830  1.900447e+05      10.079214    931.804728
# std     9535.416746    13.917588  1.057902e+05       2.590118   6496.962999
# min        3.000000    17.000000  1.882700e+04       1.000000      0.000000
# 25%     8078.000000    28.000000  1.186520e+05       9.000000      0.000000
# 50%    16626.000000    37.000000  1.783190e+05      10.000000      0.000000
# 75%    24743.000000    48.000000  2.364360e+05      12.000000      0.000000
# max    32559.000000    90.000000  1.033222e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count   3257.000000     3248.000000
# mean      92.336199       40.468288
# std      415.732721       12.598546
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     3900.000000       99.000000

# %%
## 범주형 컬럼 통계값 확인 (describe 똑같이 사용, include='O' 옵션 사용)
train.describe(include='O')
# Out:
#        workclass education      marital.status      occupation relationship  \
# count      27642     29304               29304           27636        29304
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       20451      9449               13466            3683        11845
#
#          race    sex native.country income
# count   29304  29304          28767  29304
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    25022  19578          26240  22263

# %%
# 범주형 컬럼 통계값 확인 (train)
train.describe(include='O')
# Out:
#        workclass education      marital.status      occupation relationship  \
# count      27642     29304               29304           27636        29304
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       20451      9449               13466            3683        11845
#
#          race    sex native.country income
# count   29304  29304          28767  29304
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    25022  19578          26240  22263

# %%
# 범주형 컬럼 통계값 확인 (test)
test.describe(include='object')
# Out:
#        workclass education      marital.status      occupation relationship  \
# count       3083      3257                3257            3082         3257
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq        2245      1052                1510             457         1348
#
#          race   sex native.country
# count    3257  3257           3211
# unique      5     2             37
# top     White  Male  United-States
# freq     2794  2212           2930

# %%
## 결측치 확인  isnull() 하면 boolean 값으로 모든 데이터에 대해 평가, sum()으로 행별 결측치 개수 확인
train.isnull().sum()
# Out:
# id                   0
# age                 12
# workclass         1662
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country     537
# income               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                  0
# age                 6
# workclass         174
# fnlwgt              0
# education           0
# education.num       0
# marital.status      0
# occupation        175
# relationship        0
# race                0
# sex                 0
# capital.gain        0
# capital.loss        0
# hours.per.week      9
# native.country     46
# dtype: int64

# %%
# 결측치 (train)
train.isnull().sum()
# Out:
# id                   0
# age                 12
# workclass         1662
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country     537
# income               0
# dtype: int64

# %%
# 결측치 (test)
test.isnull().sum()
# Out:
# id                  0
# age                 6
# workclass         174
# fnlwgt              0
# education           0
# education.num       0
# marital.status      0
# occupation        175
# relationship        0
# race                0
# sex                 0
# capital.gain        0
# capital.loss        0
# hours.per.week      9
# native.country     46
# dtype: int64

# %%
### 빈도수 확인 (각 target에 대한 빈도수)
train['income'].value_counts() ## 이진 분류인지 / 불균형 데이터인지 파악(7:3)
# Out:
# income
# <=50K    22263
# >50K      7041
# Name: count, dtype: int64

# %%
# label(target)별 개수 확인
train['income'].value_counts()
# Out:
# income
# <=50K    22263
# >50K      7041
# Name: count, dtype: int64

# %% [markdown]
# # 4. 데이터 전처리

# %% [markdown]
# 1. 결측치 처리 (결측치가 있다면 필수)
# 2. 이상치 처리 (선택)
# 3. 인코딩 (범주형 데이터가 있다면 필수)
# 4. 스케일링 (선택)

# %% [markdown]
# ## 1. 결측치 처리
# - 범주형
# - 수치형

# %% [markdown]
# ### 결측치 삭제

# %%
# 결측치가 있는 데이터(행) 전체 삭제 및 확인 dropna() / 기본값 axis=0
print("처리전:", train.shape)
df = train.dropna()
print("처리후:", df.shape)
# Out:
# 처리전: (29304, 16)
# 처리후: (27096, 16)

# %%
## 결측치 처리 - 결측치 삭제 (결측치를 포함한 행 전체 삭제) : 삭제 전후 데이터 크기 확인
print("삭제 전 : ", train.shape)
df = train.dropna()
print("삭제 후 : ", df.shape)
# Out:
# 삭제 전 :  (29304, 16)
# 삭제 후 :  (27096, 16)

# %%
## 결측치가 있는 컬럼의 특정 행 삭제
df = train.dropna(subset=['native.country','workclass'])
df.isnull().sum()   ## subset=['행']으로 삭제된 결측치 행 확인
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         6
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
# 결측치가 있는 특정컬럼 데이터(행)삭제
df = train.dropna(subset=['native.country','workclass'])
df.isnull().sum()
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         6
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
# 결측치가 있는 컬럼 삭제 dropna(axis=1)
print("처리전:", train.shape)
df = train.dropna(axis=1)
print("처리후:", df.shape)
# Out:
# 처리전: (29304, 16)
# 처리후: (29304, 11)

# %%
## 결측치가 있는 '컬럼' 삭제 dropna(axis=1)
print("처리 전 : ", train.shape)
df = train.dropna(axis=1)  ## 컬럼 삭제 옵션에 axis=1을 추가해주면 됨
print("처리 후 : ", df.shape)
# Out:
# 처리 전 :  (29304, 16)
# 처리 후 :  (29304, 11)

# %%
## 결측치가 많은 특정 컬럼 삭제 drop()
print("처리 전 : ", train.shape)
df = train.drop(['native.country','workclass'], axis=1)  ## dropna() 쓰면 안 되고, drop() 써야 한다
print("처리 전 : ", df.shape)
# Out:
# 처리 전 :  (29304, 16)
# 처리 전 :  (29304, 14)

# %%
# 결측치가 많은 특정 컬럼 삭제 drop
print("처리전:", train.shape)
df = train.drop(['native.country','workclass'], axis=1)
print("처리후:", df.shape)
# Out:
# 처리전: (29304, 16)
# 처리후: (29304, 14)

# %% [markdown]
# ### 결측치 채우기 (범주형)

# %%
# 최빈값
m = train['workclass'].mode()[0]
train['workclass'] = train['workclass'].fillna(m)

m = train['native.country'].mode()[0]
train['native.country'] = train['native.country'].fillna(m)

train.isnull().sum()
# Out:
# id                   0
# age                 12
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country       0
# income               0
# dtype: int64

# %%
## 결측치를 최빈값으로 채우기 (범주형 : object)
m = train['workclass'].mode()[0] ## mode()로 최빈값을 순서대로 찾고 [0]로 가장 큰 값 선택
train['workclass'] = train['workclass'].fillna(m) ## Na(결측치) 값에 그대로 대입

m = train['native.country'].mode()[0]
train['native.country'] = train['native.country'].fillna(m)

train.isnull().sum()  ## 결측치 제거 확인
# Out:
# id                   0
# age                 12
# workclass            0
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week      13
# native.country       0
# income               0
# dtype: int64

# %%
# 결측값을 새로운 카테고리로 생성 X_train['occupation']
train['occupation'] = train['occupation'].fillna('X')
train.isnull().sum()
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         0
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
### 있는 값이 아닌 아예 새로운 카테고리로 생성하여 결측치 제거 X_train['occupation']
train['occupation'] = train['occupation'].fillna('X')
train.isnull().sum()
# Out:
# id                 0
# age               12
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# marital.status     0
# occupation         0
# relationship       0
# race               0
# sex                0
# capital.gain       0
# capital.loss       0
# hours.per.week    13
# native.country     0
# income             0
# dtype: int64

# %%
# test데이터
test['workclass'] = test['workclass'].fillna(train['workclass'].mode()[0])
test['native.country']  = test['native.country'].fillna(train['native.country'].mode()[0])
test['occupation'] = test['occupation'].fillna("X")

# %%
## 테스트 데이터에도 동일하게 적용
test['workclass'] = test['workclass'].fillna(train['workclass'].mode()[0])
test['native.country'] = test['native.country'].fillna(train['native.country'].mode()[0])
test['occupation'] = test['occupation'].fillna('X')

# %% [markdown]
# ### 결측치 채우기 (수치형)

# %%
### age 컬럼 결측치를 평균값으로 채우기
value = int(train['age'].mean())  ## 평균값 내장 함수 = mean()
print("평균 값 : ", value)
train['age'] = train['age'].fillna(value)  ## 훈련 데이터 결측치 채우기
test['age'] = test['age'].fillna(value)  ## 테스트 데이터 결측치 채우기
# Out:
# 평균 값 :  38

# %%
# age 컬럼 평균값으로 채우기
value = int(train['age'].mean())
print("평균값:", value)
train['age'] = train['age'].fillna(value)
test['age'] = test['age'].fillna(value)
# Out:
# 평균값: 38

# %%
## 주당 근무시간 컬럼값 결측치 중앙값으로 채우기
value = int(train['hours.per.week'].median())
print("중앙값 : ", value)
train['hours.per.week'] = train['hours.per.week'].fillna(value)
test['hours.per.week'] = test['hours.per.week'].fillna(value)
# Out:
# 중앙값 :  40

# %%
train.isnull().sum()
# Out:
# id                0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
# 주당 근무시간 중앙값으로 채우기
value = int(train['hours.per.week'].median())
print("중앙값:", value)
train['hours.per.week'] = train['hours.per.week'].fillna(value)
test['hours.per.week'] = test['hours.per.week'].fillna(value)
# Out:
# 중앙값: 40

# %%
train.isnull().sum() #### 모든 결측치 제거됨
# Out:
# id                0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %% [markdown]
# ## 이상치 처리

# %%
train.describe()
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29304.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.552996  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.626025  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29304.000000
# mean      86.744506       40.434036
# std      401.518928       12.321306
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
train.describe()  ## 기초통계값 확인
# Out:
#                  id           age        fnlwgt  education.num  capital.gain  \
# count  29304.000000  29304.000000  2.930400e+04   29304.000000  29304.000000
# mean   16264.027880     38.552996  1.897488e+05      10.080842   1093.858722
# std     9384.518323     13.626025  1.055250e+05       2.570824   7477.435640
# min        0.000000    -38.000000  1.228500e+04       1.000000      0.000000
# 25%     8145.750000     28.000000  1.177890e+05       9.000000      0.000000
# 50%    16253.500000     37.000000  1.783765e+05      10.000000      0.000000
# 75%    24374.250000     48.000000  2.370682e+05      12.000000      0.000000
# max    32560.000000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital.loss  hours.per.week
# count  29304.000000    29304.000000
# mean      86.744506       40.434036
# std      401.518928       12.321306
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
## train 데이터에서 음수값 존재 확인
train[train['age']<=0]
# Out:
#           id   age workclass  fnlwgt     education  education.num  \
# 39     29188 -33.0   Private  263561  Some-college             10
# 79     14325 -38.0   Private   22245       HS-grad              9
# 26161   4292 -25.0   Private  200681  Some-college             10
#
#            marital.status       occupation relationship   race   sex  \
# 39     Married-civ-spouse     Craft-repair      Husband  White  Male
# 79     Married-civ-spouse  Exec-managerial      Husband  White  Male
# 26161       Never-married                X    Own-child  White  Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 39                0             0            60.0  United-States   >50K
# 79                0             0            60.0  United-States   >50K
# 26161             0             0            40.0  United-States  <=50K

# %%
### test 데이터 분포와 비교
test[test['age']<=0]  ## 나이는 무조건 양수로 존재
# Out:
# Empty DataFrame
# Columns: [id, age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country]
# Index: []

# %%
train[train['age']<=0]
# Out:
#           id   age workclass  fnlwgt     education  education.num  \
# 39     29188 -33.0   Private  263561  Some-college             10
# 79     14325 -38.0   Private   22245       HS-grad              9
# 26161   4292 -25.0   Private  200681  Some-college             10
#
#            marital.status       occupation relationship   race   sex  \
# 39     Married-civ-spouse     Craft-repair      Husband  White  Male
# 79     Married-civ-spouse  Exec-managerial      Husband  White  Male
# 26161       Never-married                X    Own-child  White  Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 39                0             0            60.0  United-States   >50K
# 79                0             0            60.0  United-States   >50K
# 26161             0             0            40.0  United-States  <=50K

# %%
test[test['age']<=0]
# Out:
# Empty DataFrame
# Columns: [id, age, workclass, fnlwgt, education, education.num, marital.status, occupation, relationship, race, sex, capital.gain, capital.loss, hours.per.week, native.country]
# Index: []

# %%
### age 값이 1 이상인 데이터만 사용
print(train.shape)
train = train[train['age']>0]
print(train.shape) ## 3개 제거됨
# Out:
# (29304, 16)
# (29301, 16)

# %%
# age가 1이상인 데이터만 살림
print(train.shape)
train = train[train['age']>0]
print(train.shape)
# Out:
# (29301, 16)
# (29301, 16)

# %% [markdown]
# 전처리 주의사항
# - 이상치, 결측치에 대해 test 데이터(행) 삭제 불가
#     - 예) test 데이터 100개가 주어지고 100개로 평가를 하는데 임의로 10개를 삭제해버리면 채점을 할 수가 없음
#     - train 데이터는 학습/훈련용 데이터임. 데이터가 많을 경우 임의로 소수 데이터(행) 삭제해도 무방함
# - test, train 컬럼은 삭제/추가 가능. 단, train과 컬럼수와 명이 일치해야 함 (y(target) 제외)

# %% [markdown]
# ## 인코딩

# %%
y_train = train.pop("income")  ## 본 모드 실행하고 재실행 시 오류 발생

# %% [markdown]
# ### 원핫(one-hot) 인코딩

# %%
train_oh = pd.get_dummies(train)
test_oh = pd.get_dummies(test)
print(train.shape, test.shape, train_oh.shape, test_oh.shape)
# Out:
# (29301, 15) (3257, 15) (29301, 107) (3257, 103)

# %%
### 원-핫 인코딩 수행
train_oh =  pd.get_dummies(train)
test_oh = pd.get_dummies(test)
print(train.shape, test.shape, train_oh.shape, test_oh.shape)
# Out:
# (29301, 15) (3257, 15) (29301, 107) (3257, 103)

# %%
print(train.shape, test.shape) ## 데이터 크기 확인
data = pd.concat([train, test], axis=0)  ## train과 test 데이터를 axis=0으로(위-아래로) 합치기 - concat()
data_oh = pd.get_dummies(data) ## 합친 데이터를 원-핫 인코딩 진행

train_oh = data_oh.iloc[:len(train)].copy()  ## train 데이터 개수 만큼 데이터 분할 iloc[:(train 개수)]  - train의 경우 앞에 :
test_oh = data_oh.iloc[len(train):].copy() ## train 데이터 개수만큼 데이터 분할(iloc[(train개수):]) - test의 경우 뒤에 :
print(train.shape, test.shape, train_oh.shape, test_oh.shape)  ## 원-핫 인코딩으로 컬럼 개수 증가 확인
# Out:
# (29301, 15) (3257, 15)
# (29301, 15) (3257, 15) (29301, 107) (3257, 107)

# %%
print(train.shape, test.shape)
data = pd.concat([train, test], axis=0)
data_oh = pd.get_dummies(data)
train_oh = data_oh.iloc[:len(train)].copy()
test_oh = data_oh.iloc[len(train):].copy()
print(train_oh.shape, test_oh.shape)
# Out:
# (29301, 15) (3257, 15)
# (29301, 107) (3257, 107)

# %% [markdown]
# ### 레이블(label) 인코딩

# %%
# cols = train.select_dtypes(include='object').columns #방법1
# cols = train.columns[train.dtypes == object] #방법2
cols = ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex','native.country']
cols
# Out:
# ['workclass',
#  'education',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native.country']

# %%
train.head(3)
# Out:
#       id   age  workclass  fnlwgt     education  education.num  \
# 0   3331  34.0  State-gov  177331  Some-college             10
# 1  19749  58.0    Private  290661       HS-grad              9
# 2   1157  48.0    Private  125933  Some-college             10
#
#        marital.status       occupation relationship   race     sex  \
# 0  Married-civ-spouse   Prof-specialty      Husband  Black    Male
# 1  Married-civ-spouse     Craft-repair      Husband  White    Male
# 2             Widowed  Exec-managerial    Unmarried  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0          4386             0            40.0  United-States
# 1             0             0            40.0  United-States
# 2             0          1669            38.0  United-States

# %%
## Label Encoding (범주형 데이터 : 데이터 값이 object 타입)
cols = ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race' ,'sex','native.country']

# %%
from sklearn.preprocessing import LabelEncoder

for col in cols:
  le = LabelEncoder()
  train[col] = le.fit_transform(train[col])
  test[col] = le.transform(test[col])

test.head()  ## 데이터 값이 수치형(Label) 값으로 변환된 것 확인
# Out:
#       id   age  workclass  fnlwgt  education  education.num  marital.status  \
# 0  11574  39.0          6  114055          9             13               4
# 1  15847  38.0          3  254114         15             10               3
# 2  17655  44.0          6   55395         11              9               4
# 3  19790  47.0          3   28035          9             13               2
# 4  31812  62.0          3  186611         11              9               4
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           3             1     4    0             0             0
# 1           9             3     2    0             0             0
# 2           2             1     4    1             0             0
# 3           3             0     4    1             0             0
# 4          14             1     4    1             0             0
#
#    hours.per.week  native.country
# 0            40.0              38
# 1            40.0              38
# 2            40.0              38
# 3            50.0              38
# 4            40.0              38

# %%
from sklearn.preprocessing import LabelEncoder

for col in cols:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

train.head()
# Out:
#       id   age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   3331  34.0          6  177331         15             10               2
# 1  19749  58.0          3  290661         11              9               2
# 2   1157  48.0          3  125933         15             10               6
# 3    693  58.0          3  100313         15             10               2
# 4  12522  41.0          3  195661         15             10               2
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           9             0     2    1          4386             0
# 1           2             0     4    1             0             0
# 2           3             4     2    0             0          1669
# 3          10             0     4    1             0          1902
# 4          13             0     4    1             0             0
#
#    hours.per.week  native.country
# 0            40.0              38
# 1            40.0              38
# 2            38.0              38
# 3            40.0              38
# 4            54.0              38

# %%
from sklearn.preprocessing import LabelEncoder

for col in cols:
  le = LabelEncoder()
  train[col] = le.fit_transform(train[col])
  test[col] = le.transform(test[col])
train.head()
# Out:
#       id   age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   3331  34.0          6  177331         15             10               2
# 1  19749  58.0          3  290661         11              9               2
# 2   1157  48.0          3  125933         15             10               6
# 3    693  58.0          3  100313         15             10               2
# 4  12522  41.0          3  195661         15             10               2
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           9             0     2    1          4386             0
# 1           2             0     4    1             0             0
# 2           3             4     2    0             0          1669
# 3          10             0     4    1             0          1902
# 4          13             0     4    1             0             0
#
#    hours.per.week  native.country
# 0            40.0              38
# 1            40.0              38
# 2            38.0              38
# 3            40.0              38
# 4            54.0              38

# %%
# from sklearn.preprocessing import LabelEncoder

# train_le = train.copy()
# test_le = test.copy()

# for col in cols:
#     le = LabelEncoder()
#     train_le[col] = le.fit_transform(train[col])
#     test_le[col] = le.transform(test[col])

# train_le.head()

# %% [markdown]
# ## 스케일링

# %%
train.head(3)
# Out:
#       id   age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   3331  34.0          6  177331         15             10               2
# 1  19749  58.0          3  290661         11              9               2
# 2   1157  48.0          3  125933         15             10               6
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           9             0     2    1          4386             0
# 1           2             0     4    1             0             0
# 2           3             4     2    0             0          1669
#
#    hours.per.week  native.country
# 0            40.0              38
# 1            40.0              38
# 2            38.0              38

# %%
### 수치형 컬럼명 리스트 변환
cols = ['age', 'fnlwgt', 'education.num','capital.gain', 'capital.loss','hours.per.week']

# %%
# 수치형 컬럼명
cols = ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']

# %%
## 데이터를 매번 새롭게 불러오는 함수 정의
def get_data():
  train_copy = train.copy()
  test_copy = test.copy()
  return train_copy, test_copy

# %%
# 데이터를 매번 새롭게 불러오기 위해 함수로 제작 함
def get_data():
    train_copy = train.copy()
    test_copy = test.copy()
    return train_copy, test_copy

# %%
## Min-Max 스케일링 수행
train_copy, test_copy = get_data()  ## 방금 정의한 함수
### 스케일러 불러오기
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
display(train_copy[cols].head(2))
## 아까 변환한 컬럼명 리스트를 인덱스로 사용
train[cols] = scaler.fit_transform(train_copy[cols])
test[cols] = scaler.transform(test_copy[cols])
display(train_copy[cols].head(2))  ## 해당 수치형 컬럼값들이 0과 1사이(실수형) 데이터로 변환 됨
# Out:
#     age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0  34.0  177331             10          4386             0            40.0
# 1  58.0  290661              9             0             0            40.0
#     age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0  34.0  177331             10          4386             0            40.0
# 1  58.0  290661              9             0             0            40.0

# %%
# train_copy, test_copy = get_data()

# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# train[cols] = scaler.fit_transform(train_copy[cols])
# test[cols] = scaler.transform(test_copy[cols])
# display(train_copy[cols].head(2))

# %%
# 민-맥스 스케일링 MinMaxScaler (모든 값이 0과 1사이)
train_copy, test_copy = get_data()

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
display(train_copy[cols].head(2))
train_copy[cols] = scaler.fit_transform(train_copy[cols])
test_copy[cols] = scaler.transform(test_copy[cols])
display(train_copy[cols].head(2))
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0  0.232877  0.112092       0.600000       0.04386           0.0
# 1  0.561644  0.189060       0.533333       0.00000           0.0
#
#    hours.per.week
# 0        0.397959
# 1        0.397959
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0  0.232877  0.112092       0.600000       0.04386           0.0
# 1  0.561644  0.189060       0.533333       0.00000           0.0
#
#    hours.per.week
# 0        0.397959
# 1        0.397959

# %%
# 표준화 StandardScaler (Z-score 정규화, 평균이 0 표준편차가 1인 표준 정규분포로 변경)
train_copy, test_copy = get_data()

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
display(train_copy[cols].head(2))
train_copy[cols] = scaler.fit_transform(train_copy[cols])
test_copy[cols] = scaler.transform(test_copy[cols])
display(train_copy[cols].head(2))
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0  0.232877  0.112092       0.600000       0.04386           0.0
# 1  0.561644  0.189060       0.533333       0.00000           0.0
#
#    hours.per.week
# 0        0.397959
# 1        0.397959
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0 -0.335121 -0.117705      -0.031462      0.440247     -0.216056
# 1  1.428590  0.956277      -0.420430     -0.146298     -0.216056
#
#    hours.per.week
# 0       -0.035121
# 1       -0.035121

# %%
### StandardScaler : 평균이 0 이고, 표준편차가 1인 표준 정규분포로 변경
train_copy, test_coopy = get_data()

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_copy[cols] = scaler.fit_transform(train_copy[cols])
test_copy[cols] = scaler.transform(test_copy[cols])

display(train_copy[cols].head(2))  ## 실수(음수~양수) 값으로 변환된 것을 확인
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0 -0.335121 -0.117705      -0.031462      0.440247     -0.216056
# 1  1.428590  0.956277      -0.420430     -0.146298     -0.216056
#
#    hours.per.week
# 0       -0.035121
# 1       -0.035121

# %%
# 로버스트 스케일링 : 중앙값과 사분위 값 활용, 이상치 영향 최소화 장점
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
display(train[cols].head(2))
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.transform(test[cols])
display(train[cols].head(2))
# Out:
#         age    fnlwgt  education.num  capital.gain  capital.loss  \
# 0  0.232877  0.112092       0.600000       0.04386           0.0
# 1  0.561644  0.189060       0.533333       0.00000           0.0
#
#    hours.per.week
# 0        0.397959
# 1        0.397959
#     age    fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0 -0.15 -0.008711       0.000000       0.04386           0.0             0.0
# 1  1.05  0.941438      -0.333333       0.00000           0.0             0.0

# %%
## 로버스트 스케일링 : 중앙값과 사분위 값 활용 - 대부분 0
# train_copy, test_copy = get_data()
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
display(train_copy[cols].head(2))
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.transform(test[cols])
display(train[cols].head(2))  ## 값 변환 확인
# Out:
#     age    fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0 -0.15 -0.008711       0.000000       0.04386           0.0             0.0
# 1  1.05  0.941438      -0.333333       0.00000           0.0             0.0
#     age    fnlwgt  education.num  capital.gain  capital.loss  hours.per.week
# 0 -0.15 -0.008711       0.000000       0.04386           0.0             0.0
# 1  1.05  0.941438      -0.333333       0.00000           0.0             0.0

# %% [markdown]
# ## target(label)

# %%
y_train.value_counts()   ## y_train 데이터 개수 확인 ("<=50K" : 22263 / ">50K" : 7041)
# Out:
# income
# <=50K    17770
# >50K      5670
# Name: count, dtype: int64

# %%
y_train.value_counts()
# Out:
# income
# <=50K    22262
# >50K      7039
# Name: count, dtype: int64

# %%
# target = y_train.map({'<=50K':0, '>50K':1})
# target.value_counts()

# %%
# target = y_train.replace('<=50K', 0).replace('>50K', 1)
# target.value_counts()

# %% [markdown]
# # 5. 검증 데이터 분할

# %%
from sklearn.model_selection import train_test_split #### sklearn에서 제공하는 model_selection 의 train_test_split 사용

X_train, X_val, y_train, y_val = train_test_split(train,
                                                  y_train,
                                                  test_size=0.2,
                                                  random_state=0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32249/851390701.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split #### sklearn에서 제공하는 model_selection 의 train_test_split 사용
#       2
# ----> 3 X_train, X_val, y_train, y_val = train_test_split(train,
#       4                                                   y_train,
#       5                                                   test_size=0.2,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2846         raise ValueError("At least one array required as input")
#    2847
# -> 2848     arrays = indexable(*arrays)
#    2849
#    2850     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     530
#     531     result = [_make_indexable(X) for X in iterables]
# --> 532     check_consistent_length(*result)
#     533     return result
#     534
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [29301, 23440]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(train,
                                                  y_train,
                                                  test_size=0.2,
                                                  random_state=0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32249/2430407244.py in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_val, y_train, y_val = train_test_split(train,
#       4                                                   y_train,
#       5                                                   test_size=0.2,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2846         raise ValueError("At least one array required as input")
#    2847
# -> 2848     arrays = indexable(*arrays)
#    2849
#    2850     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     530
#     531     result = [_make_indexable(X) for X in iterables]
# --> 532     check_consistent_length(*result)
#     533     return result
#     534
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [29301, 23440]

# %%
# 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)
pred=rf.predict_proba(X_val) # 각 레이블에 속할 확률 값 반환

print(rf.classes_)
pred[:10]

# %% [markdown]
# # 6. 머신러닝 학습 및 평가

# %%
# 랜덤포레스트
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)
pred=rf.predict_proba(X_val) # 각 레이블에 속할 확률 값 반환
pred[:10]
# Out:
# array([[1.  , 0.  ],
#        [1.  , 0.  ],
#        [0.9 , 0.1 ],
#        [0.63, 0.37],
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.98, 0.02],
#        [0.94, 0.06],
#        [0.12, 0.88],
#        [0.88, 0.12]])

# %%
## 랜덤 포레스트 사용
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=0)   ## random_state=0 으로 값 고정하여 진행
rf.fit(X_train, y_train)   ## 학습
pred = rf.predict_proba(X_val)

print(rf.classes_) ### 예측된 각 레이블(Label)
pred[:10]   ## 레이블(Lebel)에 속할 확률값
# Out:
# ['<=50K' '>50K']
# array([[1.  , 0.  ],
#        [1.  , 0.  ],
#        [0.9 , 0.1 ],
#        [0.63, 0.37],
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.98, 0.02],
#        [0.94, 0.06],
#        [0.12, 0.88],
#        [0.88, 0.12]])

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)  ## 학습 수행
pred = rf.predict_proba(X_val)  ## 예측 수행 - predict_proba() 함수 : rf 내장, X_val을 변수로 사용

print(rf.classes_)
pred[:10]
# Out:
# ['<=50K' '>50K']
# array([[1.  , 0.  ],
#        [1.  , 0.  ],
#        [0.9 , 0.1 ],
#        [0.63, 0.37],
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.98, 0.02],
#        [0.94, 0.06],
#        [0.12, 0.88],
#        [0.88, 0.12]])

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=0)  ## 랜덤 포레스트
rf.fit(X_train, y_train) ## 학습
pred = rf.predict_proba(X_val)  ## 예측

print(rf.classes_)
pred[:10]
# Out:
# ['<=50K' '>50K']
# array([[1.  , 0.  ],
#        [1.  , 0.  ],
#        [0.9 , 0.1 ],
#        [0.63, 0.37],
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.98, 0.02],
#        [0.94, 0.06],
#        [0.12, 0.88],
#        [0.88, 0.12]])

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_val, pred[:,1])
print('roc_auc:', roc_auc)
# Out:
# roc_auc: 0.9173623004487484

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_val, pred[:,1])  ## 두 번째 열인 ">50K"의 확률로 예측 수행
print("roc_auc : ", roc_auc)
# Out:
# roc_auc :  0.9173623004487484

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_val, pred[:,1])
print('roc_auc : ', roc_auc)

pred = rf.predict(X_val)
pred[:10]
# Out:
# roc_auc :  0.9173623004487484
# array(['<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K',
#        '<=50K', '>50K', '<=50K'], dtype=object)

# %%
pred = rf.predict(X_val)  ## 예측된 각 레이블(Label) 이름 반환
pred[:10] ## 그 중에 10개 꺼내 봄
# Out:
# array(['<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K',
#        '<=50K', '>50K', '<=50K'], dtype=object)

# %%
pred = rf.predict(X_val) # 예측된 각 레이블 반환
pred[:10]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_val, pred)
print('accuracy_score:', accuracy)

# %%
### 정확도 결과 확인
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_val, pred)
print("accuracy : ", accuracy)
# Out:
# accuracy :  0.8694761986009213

# %%
# from sklearn.metrics import accuracy_score
# accuracy = accuracy_score(y_val, pred)
# print('accuracy : ', accuracy)
# Out:
# accuracy :  0.8694761986009213

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_val, pred, pos_label='>50K')
print('f1_score:', f1)

# %%
### f1-score 확인하기
from sklearn.metrics import f1_score
f1 = f1_score(y_val, pred, pos_label='>50K') ## Label명이 범주형이므로 수치형(0,1)으로 변환해야 해서 pos_label='>50K'
print('f1_score : ', f1) ## 정밀도-재현율에 관한 f1_score
# Out:
# f1_score :  0.6926476496584973

# %%
# LightGBM
import lightgbm as lgb
lgbmc = lgb.LGBMClassifier(random_state=0, verbose=-1)
lgbmc.fit(X_train, y_train)
pred = lgbmc.predict_proba(X_val)

roc_auc = roc_auc_score(y_val, pred[:,1])
print('roc_auc:', roc_auc)

pred = lgbmc.predict(X_val)
accuracy = accuracy_score(y_val, pred)
print('accuracy_score:', accuracy)

f1 = f1_score(y_val, pred, pos_label='>50K')
print('f1_score:', f1)
#### LightGBM은 일단 보류한다
# Out:
# roc_auc: 0.9279535666686397
# accuracy_score: 0.8771540692714553
# f1_score: 0.7158642462509865

# %% [markdown]
# # 7. 예측 및 결과 파일 생성

# %%
pred = lgbmc.predict_proba(test)
pred ## 첫 번째 값 : "<=50K", 두 번째 값 : ">50K"
# Out:
# array([[0.89924007, 0.10075993],
#        [0.97622077, 0.02377923],
#        [0.9853122 , 0.0146878 ],
#        ...,
#        [0.93528667, 0.06471333],
#        [0.98996872, 0.01003128],
#        [0.96723292, 0.03276708]])

# %%
pred = lgbmc.predict_proba(test)
pred

# %%
lgbmc.classes_  ## 데이터 레이블 확인 (데이터 타입까지 확인 가능)
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
submit = pd.DataFrame({'pred':pred[:,1]})
submit.to_csv("result.csv", index=False)

# %%
submit = pd.DataFrame({'pred':pred[:,1]})
submit.to_csv("result.csv", index=False) ## 기존 인덱스 없이 result.csv 파일로 저장

# %%
# submit = pd.DataFrame({'pred':pred[:,1]})
# submit.to_csv("result.csv", index=False)

# %%
# submit = pd.DataFrame({'pred':pred[:,1]})
# submit.to_csv("result.csv", index=False)

# %%
pd.read_csv("result.csv") ## 만든 파일(결과물)  ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  확인
# Out:
#           pred
# 0     0.100760
# 1     0.023779
# 2     0.014688
# 3     0.798048
# 4     0.026542
# ...        ...
# 3252  0.009613
# 3253  0.321992
# 3254  0.064713
# 3255  0.010031
# 3256  0.032767
#
# [3257 rows x 1 columns]
